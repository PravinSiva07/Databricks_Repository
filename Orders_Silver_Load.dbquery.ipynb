-- %%
CREATE OR REPLACE TABLE dw_lnd_dev.dw_lnd.orders_silver AS
select 'Pravin' as Name
UNION
select 'Lavanya';

-- CREATE OR REPLACE TABLE dw_lnd_dev.dw_lnd.orders_silver AS
-- SELECT
--     order_id,
--     order_date,
--     ship_date,
--     ship_mode,
--     customer_id,
--     region,
--     product_id,
--     category,
--     sales,
--     quantity,
--     profit,
--     SourceFileName,
--     Ingested_Date,
--     RunID,
--     Job_Name
-- FROM dw_lnd_dev.dw_lnd.orders_bronze
-- WHERE RunID = :run_id
;

--Dummy Query
